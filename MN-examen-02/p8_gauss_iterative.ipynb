# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Ejercicio 1

# %%
from src import gauss_jordan_inversa


A = [[2,1],[3,2]]
b = [5,8]



A_inv = gauss_jordan_inversa(A)
print(A_inv)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from src import gauss_jordan_inversa
#       4 A = [[2,1],[3,2]]
#       5 b = [5,8]
#
# ImportError: cannot import name 'gauss_jordan_inversa' from 'src' (c:\Users\Lasca\Documents\4to Semestre\numericalmethods\MN-Examen2\MN-examen-02\src\__init__.py)

# %% [markdown]
# # Ejercicio 2

# %%
# %autoreload 2
from src import gauss_jacobi, gauss_seidel
A = [[1,1],[-2,1]]
b = [6,0]

gauss_jacobi(A,b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 6
#       3 A = [[1,1],[-2,1]]
#       4 b = [6,0]
# ----> 6 gauss_jacobi(A,b)
#
# TypeError: gauss_jacobi() takes 0 positional arguments but 2 were given

# %% [markdown]
# # Código para dibujar

# %%
# Extraer valores de la trayectoria
# -- Datos de ejemplo --
x_values = [0, 1, 0.5, 2, 2.5, 2.75, 2.9, 3.0]
y_values = [4.5, 5, 5.5, 4, 3.5, 3.25, 3.1, 3.0]

import matplotlib.pyplot as plt

iterations = range(len(x_values))

# Dibujar trajectoria en el espacio 2D
plt.plot(x_values, y_values, "o:", markersize=4)
plt.plot(x_values[0], y_values[0], "gd", markersize=8, label="$X_0$", alpha=0.8)
plt.plot(x_values[-1], y_values[-1], "ro", markersize=8, label="$X_{sol}$", alpha=0.8)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Trajectoria")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
